# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
cd ..

# %%
cd gdrive/My Drive/Colab Notebooks/study NLP/model
# Out:
# /gdrive/My Drive/Colab Notebooks/study NLP/model

# %%
ls
# Out:
# eng_w2v

# %%
# !python -m gensim.scripts.word2vec2tensor --input eng_w2v --output eng_w2v
# Out:
# 2022-01-25 09:17:27,852 - word2vec2tensor - INFO - running /usr/local/lib/python3.7/dist-packages/gensim/scripts/word2vec2tensor.py --input eng_w2v --output eng_w2v
# 2022-01-25 09:17:27,852 - utils_any2vec - INFO - loading projection weights from eng_w2v
# 2022-01-25 09:17:30,597 - utils_any2vec - INFO - loaded (21613, 100) matrix from eng_w2v
# 2022-01-25 09:17:32,677 - word2vec2tensor - INFO - 2D tensor file saved to eng_w2v_tensor.tsv
# 2022-01-25 09:17:32,677 - word2vec2tensor - INFO - Tensor metadata file saved to eng_w2v_metadata.tsv
# 2022-01-25 09:17:32,680 - word2vec2tensor - INFO - finished running word2vec2tensor.py
